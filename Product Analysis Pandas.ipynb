# %% [markdown]
# ## Product analysis using Pandas

# %%
import pandas as pd
import os

# %%
##Merge 12 months of data into file
df = pd.DataFrame()
files = [file for file in os.listdir("./Sales_Data")]
files.remove('.ipynb_checkpoints')
for file in files:
    new = pd.read_csv("./Sales_data/"+file,engine='python')
    df = pd.concat([df,new])

# %%
df.to_csv('all_data.csv',index=False)

# %%
#Read in updated
df = pd.read_csv('all_data.csv')
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# ## Clean up Data

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# Month                 0
# Day                   0
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
## Add some columns

#Two different ways
df['Month'] = df['Order Date'].str[0:2]
df['Day'] = [str(val)[3:5] for val in df['Order Date']]

df = df[~df['Month'] !='Or']
df['Month'] = df['Month'].astype('int32')
df['Day'] = df['Day'].astype('int32')

# %%
## What was the best month for sales? How much $$ earned?
df['Price Each'] = pd.to_numeric(df['Price Each'])
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Sales'] = df['Price Each']*df['Quantity Ordered']

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  Day    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12   30  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12   29   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12   12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   22   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12   18    11.95

# %%
results = df.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD($)')
plt.xlabel('Month')
plt.show()

# %%
#What city had highest number of sales?

df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  Day    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12   30  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12   29   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12   12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   22   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12   18    11.95

# %%
#Add City column
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2][1:3]
df['City'] = df['Purchase Address'].apply(lambda x:get_city(x) + ' ' +get_state(x))

# %%
results = df.groupby('City').sum()
results
# Out:
#                    Quantity Ordered    Price Each   Month     Day  \
# City
#  Atlanta GA                   16602  2.779908e+06  104794  234837
#  Austin TX                    11153  1.809874e+06   69829  156782
#  Boston MA                    22528  3.637410e+06  141112  312376
#  Dallas TX                    16730  2.752628e+06  104620  234435
#  Los Angeles CA               33289  5.421435e+06  208325  469607
#  New York City NY             27932  4.635371e+06  175741  392706
#  Portland ME                   2750  4.471893e+05   17144   38288
#  Portland OR                  11303  1.860558e+06   70621  159233
#  San Francisco CA             50239  8.211462e+06  315520  702669
#  Seattle WA                   16553  2.733296e+06  104941  229552
#
#                           Sales
# City
#  Atlanta GA        2.795499e+06
#  Austin TX         1.819582e+06
#  Boston MA         3.661642e+06
#  Dallas TX         2.767975e+06
#  Los Angeles CA    5.452571e+06
# ...

# %%
cities = [city for city, adf in df.groupby('City')]

plt.bar(cities,results['Sales'])
plt.xticks(cities, rotation='vertical',size=8)
plt.ylabel('Sales in USD($)')
plt.xlabel('Month')
plt.show()

# %%
# What time should we display advertisements to maximize likelihood of customer buying product

df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  Day  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12   30
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12   29
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12   12
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   22
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12   18
#
#      Sales               City
# 0  1700.00   New York City NY
# 1   600.00   New York City NY
# 2    11.95   New York City NY
# 3   149.99   San Francisco CA
# ...

# %%
import datetime as dt
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Hour'] = df['Order Date'].dt.hour
df['Minute'] = df['Order Date'].dt.minute

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Month  Day  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12   30
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   29
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12   12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   22
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12   18
#
#      Sales               City  Hour  Minute
# 0  1700.00   New York City NY     0       1
# 1   600.00   New York City NY     7       3
# ...

# %%
hours = [hour for hour, adf in df.groupby('Hour')]

plt.plot(hours,df.groupby('Hour').count())
plt.xticks(hours)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()

# %%
#What products are most often sold together?

df.head(5)
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Month  Day  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12   30
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   29
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12   12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   22
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12   18
#
#      Sales               City  Hour  Minute
# 0  1700.00   New York City NY     0       1
# 1   600.00   New York City NY     7       3
# ...

# %%
orders_df = df[df['Order ID'].duplicated(keep=False)]

# %%
orders_df['Grouped']=orders_df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
orders_df.head()
# Out:
# <ipython-input-124-4ee903fcf217>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_df['Grouped']=orders_df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 16   295681                Google Phone                 1      600.00
# 17   295681        USB-C Charging Cable                 1       11.95
# 18   295681  Bose SoundSport Headphones                 1       99.99
# 19   295681            Wired Headphones                 1       11.99
# 36   295698             Vareebadd Phone                 1      400.00
#
#             Order Date                     Purchase Address  Month  Day  \
# ...

# %%
orders_df = orders_df[['Order ID','Grouped']].drop_duplicates()
orders_df.head()
# Out:
#    Order ID                                            Grouped
# 16   295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36   295698               Vareebadd Phone,USB-C Charging Cable
# 42   295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66   295726                    iPhone,Lightning Charging Cable
# 76   295735   iPhone,Apple Airpods Headphones,Wired Headphones

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in orders_df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))

count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
#What product sold the most?

df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Month  Day  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12   30
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   29
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12   12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   22
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12   18
#
#      Sales               City  Hour  Minute
# 0  1700.00   New York City NY     0       1
# 1   600.00   New York City NY     7       3
# ...

# %%
results = df.groupby('Product').sum()['Quantity Ordered'].sort_values(ascending=False)
# Out:
# Product
# AAA Batteries (4-pack)        31017
# AA Batteries (4-pack)         27635
# USB-C Charging Cable          23975
# Lightning Charging Cable      23217
# Wired Headphones              20557
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# 27in FHD Monitor               7550
# iPhone                         6849
# 27in 4K Gaming Monitor         6244
# 34in Ultrawide Monitor         6199
# Google Phone                   5532
# Flatscreen TV                  4819
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# 20in Monitor                   4129
# Vareebadd Phone                2068
# LG Washing Machine              666
# LG Dryer                        646
# Name: Quantity Ordered, dtype: int64
